# %% [markdown]
# # EXCEPTION HANDLING

# %%
a = 5
b = 0
print(a/b)                    # it show error due to it is divide by 0 
print('Well Done')            # it is written after the error show it will also not print
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-3019a4f66880> in <module>()
#       1 a = 5
#       2 b = 0
# ----> 3 print(a/b)                    # it show error due to it is divide by 0
#       4 print('Well Done')            # it is written after the error show it will also not print
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Try Except Block

# %%
a = 5
b = 0
try:
  print(a/b)
except Exception:
  print('Division By 0 is not allowed')
print('Well Done')
# Out:
# Division By 0 is not allowed
# Well Done

# %%
a = 5
b = 0
try:
  print(a/b)
except Exception as e:
  print('The error is :', e)
print('Well Done')
# Out:
# The error is : division by zero
# Well Done

# %%
try:
  a = int(input('Enter some word: '))
  print(a)
except Exception as e:
  print('The error is :', e)
print('Well Done')
# Out:
# Enter some word: 5
# 5
# Well Done

# %%
a, b = 10, 0
try:
  x = int(input('Enter some number: '))
  print(x)
  print(a/b)
except ZeroDivisionError as e:
  print('The error is e: ',e)
except ValueError as e:
  print('Input is not valid')
except Exception as e:
  print('The error is :', e)
# Out:
# Enter some number: 5
# 5
# The error is e:  division by zero

# %% [markdown]
# ## Try Except

# %%
a, b = 10, 0
try:
  x = int(input('Enter some number: '))
  print(x)
  print(a/b)
except ZeroDivisionError as e:
  print('The error is e: ',e)
except ValueError as e:
  print('Input is not valid')
except Exception as e:
  print('The error is :', e)
finally:
  print('The Exception Handled')
# Out:
# Enter some number: 5
# 5
# The error is e:  division by zero
# The Exception Handled

# %%
while True:
  try:
   x = int(input('Enter some number: '))
   print(x)
   print(a/b)
  except ZeroDivisionError as e:
    print('The error is e: ',e)
  except ValueError as e:
    print('Input is not valid')
  except Exception as e:
    print('The error is :', e)
  finally:
    print('The Exception Handled')
# Out:
# Enter some number: 4
# 4
# The error is e:  division by zero
# The Exception Handled
# Enter some number: 5
# 5
# The error is e:  division by zero
# The Exception Handled
# Enter some number: 54
# 54
# The error is e:  division by zero
# The Exception Handled
# Enter some number: python
# Input is not valid
# The Exception Handled
# The Exception Handled
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     726         """
# --> 727         parts = [self.recv(flags, copy=copy, track=track)]
#     728         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-358204a41073> in <module>()
#       1 while True:
#       2   try:
# ----> 3    x = int(input('Enter some number: '))
#       4    print(x)
#       5    print(a/b)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
x = 0
while x < 5:
  try:
    if (x != 0):
      print('x = {0}'.format(x))
  except:
      continue
  finally:
      x += 1
# Out:
# x = 1
# x = 2
# x = 3
# x = 4

# %%
def func():
  for num in range(5):
    try:
      print(num)
    finally:
      continue
func()
# Out:
#   File "<ipython-input-19-6c5142ed01dd>", line 6
#     continue
#     ^
# SyntaxError: 'continue' not supported inside 'finally' clause
